# %% [markdown]
# # Lille

# %%
import pandas as pd
import numpy as np
import csv
import sys
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.externals import joblib
pd.set_option("max_colwidth", 4000)

# %% [markdown]
# # <font color = "blue"> Propositions</font>

# %%
dataframe_propositions = pd.read_csv("./data/LILLE/2019-74385-propositions.csv", delimiter=";")

# %%
dataframe_propositions
# Out:
#      id  category/id                                  category/name/fr  \
# 0   425         41.0                          La transition écologique
# 1   417         42.0            La fiscalité et les dépenses publiques
# 2   341         42.0            La fiscalité et les dépenses publiques
# 3   430         41.0                          La transition écologique
# 4   391         44.0  L'organisation de l’État et des services publics
# 5   419         45.0                                       Autre sujet
# 6   343         42.0            La fiscalité et les dépenses publiques
# 7   421         41.0                          La transition écologique
# 8   357         45.0                                       Autre sujet
# 9   422         43.0                   La démocratie et la citoyenneté
# 10  344         43.0                   La démocratie et la citoyenneté
# 11  423         41.0                          La transition écologique
# ...

# %% [markdown]
# ## Titre propositions

# %%
titles_columns = dataframe_propositions.columns
print(titles_columns)
# Out:
# Index(['id', 'category/id', 'category/name/fr', 'scope/id', 'scope/name',
#        'author_id', 'title', 'body', 'votes', 'comments', 'created_at',
#        'published_at', 'hidden', 'url', 'component/id', 'meeting_urls'],
#       dtype='object')

# %% [markdown]
# ## Shape Proposition

# %%
shape_df = dataframe_propositions.shape
print(shape_df)
# Out:
# (69, 16)

# %% [markdown]
# # <font color = "green">Commentaires</font>

# %%
dataframe_commentaire = pd.read_csv("./data/LILLE/2019-74367-commentaires.csv",delimiter=";")

# %%
dataframe
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ## Titres commentaires

# %%
titles_columns = dataframe_commentaire.columns
print(titles_columns)
# Out:
# Index(['id', 'created_at', 'body', 'author/id', 'author/name', 'alignment',
#        'depth', 'user_group/id', 'user_group/name/fr', 'commentable_id',
#        'commentable_type', 'root_commentable_url'],
#       dtype='object')

# %% [markdown]
# ## Shape commentaires

# %%
shape_df = dataframe_commentaire.shape
print(shape_df)
# Out:
# (44, 12)
