# %% [markdown]
# ## MEL

# %%
import pandas as pd
import numpy as np
import csv
import sys
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.externals import joblib
pd.set_option("max_colwidth", 4000)

# %%
dataframe_contrib = pd.read_csv("./data/MEL/grand-debat-participation-citoyenne-mel-contribution-libres.csv", delimiter= ";",error_bad_lines=False)

# %%
dataframe_reponse = pd.read_csv("./data/MEL/grand-debat-reponses-aux-questions-du-president.csv", delimiter=";",error_bad_lines = False)

# %% [markdown]
# # <font color = "blue">Propositions</font>

# %%
dataframe_contrib
# Out:
#                                                Thématiques  \
# 0                                Démocratie et citoyenneté
# 1                                Démocratie et citoyenneté
# 2                                Démocratie et citoyenneté
# 3                                Démocratie et citoyenneté
# 4                                Démocratie et citoyenneté
# 5                        Impôts, dépenses, action publique
# 6                        Impôts, dépenses, action publique
# 7                        Impôts, dépenses, action publique
# 8                        Impôts, dépenses, action publique
# 9                        Impôts, dépenses, action publique
# 10                       Impôts, dépenses, action publique
# 11                       Impôts, dépenses, action publique
# 12                       Impôts, dépenses, action publique
# 13                       Impôts, dépenses, action publique
# 14                       Impôts, dépenses, action publique
# ...

# %% [markdown]
# # <font color = "green"> Réponses</font>

# %%
dataframe_reponse
# Out:
#                                                                                                                                                                                                                            Question  \
# 0                                                                                                                                                          Comment pourrait-on rendre notre fiscalité plus juste et plus efficace ?
# 1                                                                                                                                                          Comment pourrait-on rendre notre fiscalité plus juste et plus efficace ?
# 2                                                                                                                                                          Comment pourrait-on rendre notre fiscalité plus juste et plus efficace ?
# ...
